# %% [markdown]
# <a href="https://colab.research.google.com/github/Lioneln5/CIS3120/blob/main/HelloWorld(Class2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello World program

# %%
print("Hello, world")
# Out:
# Hello, world

# %%
print("Hello again")

# %% [markdown]
# My hello world program now works.
